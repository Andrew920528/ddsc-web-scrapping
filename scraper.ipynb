# %% [markdown]
# ### Step 0: Set up environment

# %%
import pandas as pd
import pprint
import requests
from bs4 import BeautifulSoup

# %%
excelPath = '/Users/yenshuohsu/DDSC/MavenWebScrapping/永豐.保管系統.Lib元件版本清單.20240630.xlsx'

# %% [markdown]
# ### Step 1: Format excel sheet to the desired format
# | Library | Vulnerabilities | Date | Url |
# | ------- | --------------- | ---- | --- |

# %%
# Read in the excel file
df = pd.read_excel(excelPath,sheet_name=0)
print(str(df.shape[0]) + " rows, " + str(df.shape[1]) + " columns")
# Out:
# 95 rows, 12 columns

# %%
# Convert to a list of dictionary to iterate through
# Assuming format is consistent. We're interested in Column G - L (7 - 12)
cropped = df.iloc[1:, 5:12] # 0 based, first row is header

libraries = cropped.iloc[:, 0]
vulnerabilities = cropped.iloc[:,1]
date= cropped.iloc[:, 3]
url = cropped.iloc[:, 5]

dependencies = []

for i in range(libraries.shape[0]):
    dependencies.append({
        "library": libraries.iloc[i],
        "vulnerabilities": vulnerabilities.iloc[i],
        "date": date.iloc[i],
        "url": url.iloc[i]
    })
pprint.pprint(dependencies[:5])
# Out:
# [{'date': '2006-07-17T00:00:00',
#   'library': 'activation-1.0.2.jar',
#   'url': 'https://mvnrepository.com/artifact/javax.xml.bind/activation',
#   'vulnerabilities': nan},
#  {'date': nan, 'library': nan, 'url': '中菲', 'vulnerabilities': nan},
#  {'date': '2007-01-14T00:00:00',
#   'library': 'antlr-3.0ea8.jar',
#   'url': 'https://mvnrepository.com/artifact/antlr/antlr',
#   'vulnerabilities': nan},
#  {'date': nan,
#   'library': 'antlr-.jar',
#   'url': 'https://mvnrepository.com/artifact/antlr/antlr',
#   'vulnerabilities': nan},
#  {'date': nan,
#   'library': 'aopalliance-.jar',
#   'url': 'https://mvnrepository.com/artifact/aopalliance/aopalliance',
#   'vulnerabilities': nan}]

# %% [markdown]
# ### step 2: loop through dependencies and scrap data from website

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

first_rows_of_version_table = []
failed_url = {}
# driver = webdriver.Chrome()
for i, dep in enumerate(dependencies[:]):
    print(f"================== {i + 1} / {len(dependencies)} ==================")
    driver = webdriver.Chrome()
    url = dep["url"]
    start_time = time.perf_counter()
    try:
        print(f"scraping: {url}")
        driver.get(url)

        table = driver.find_element(By.CLASS_NAME, 'versions')
        thead = table.find_element(By.TAG_NAME, 'thead')
        tr = thead.find_element(By.TAG_NAME, "tr")
        ths = tr.find_elements(By.TAG_NAME, "th")
        
        headers= []
        for th in ths:
            headers.append(th.text)
        
        tbody = table.find_element(By.TAG_NAME, 'tbody')
        first_row = tbody.find_element(By.TAG_NAME, 'tr')
        cells = first_row.find_elements(By.TAG_NAME, 'td')

        rowData = {}
        for i, cell in enumerate(cells):
            try:
                x = cell.text
            except:
                x = ""
            rowData[headers[i]] =  x
        
        
    except Exception as e:
        # invalid url
        print(f"Encountered error, pay attention to this url: {url}")
        rowData = {
            "Version" : "",
            "Vulnerabilities" : "",
            "Date" : ""
        }
        
        failed_url[i] = url
    finally:
        driver.close()
        # pass


    end_time = time.perf_counter()
    elapsed_time = end_time - start_time
    print(rowData)
    first_rows_of_version_table.append(rowData)
    print(f"Elapsed time: {elapsed_time} seconds")
    
print("Here are the urls that failed during fetching:")
print(failed_url)
driver.quit()
# Out:
# ================== 1 / 94 ==================
# scraping: https://mvnrepository.com/artifact/javax.xml.bind/activation
# {'Version': '1.0.2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '42', 'Date': 'Jul 17, 2006'}
# Elapsed time: 94.75768275000155 seconds
# ================== 2 / 94 ==================
# scraping: 中菲
# Encountered error, pay attention to this url: 中菲
# {'Version': '', 'Vulnerabilities': '', 'Date': ''}
# Elapsed time: 0.15900629200041294 seconds
# ================== 3 / 94 ==================
# scraping: https://mvnrepository.com/artifact/antlr/antlr
# {'Version': '3.0ea8', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '0', 'Date': 'Jan 14, 2007'}
# Elapsed time: 91.26304037502268 seconds
# ================== 4 / 94 ==================
# scraping: https://mvnrepository.com/artifact/antlr/antlr
# {'Version': '3.0ea8', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '0', 'Date': 'Jan 14, 2007'}
# Elapsed time: 89.8800363339833 seconds
# ================== 5 / 94 ==================
# scraping: https://mvnrepository.com/artifact/aopalliance/aopalliance
# {'Version': '1.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '937', 'Date': 'Dec 28, 2015'}
# Elapsed time: 88.64978812501067 seconds
# ================== 6 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.ow2.asm/asm
# {'': '9.7.x', 'Version': '9.7', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '228', 'Date': 'Mar 23, 2024'}
# Elapsed time: 104.59498562500812 seconds
# ================== 7 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.ow2.asm/asm-commons
# {'': '9.7.x', 'Version': '9.7', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '90', 'Date': 'Mar 23, 2024'}
# Elapsed time: 88.9437426669756 seconds
# ================== 8 / 94 ==================
# scraping: https://mvnrepository.com/artifact/cglib/cglib-nodep
# {'': '3.3.x', 'Version': '3.3.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '220', 'Date': 'Aug 12, 2019'}
# Elapsed time: 84.81043912499445 seconds
# ================== 9 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.webjars.npm/chardet
# {'Version': '1.4.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '0', 'Date': 'Jun 14, 2023'}
# Elapsed time: 88.96140200004447 seconds
# ================== 10 / 94 ==================
# scraping: 中菲
# Encountered error, pay attention to this url: 中菲
# {'Version': '', 'Vulnerabilities': '', 'Date': ''}
# Elapsed time: 0.2780023330124095 seconds
# ================== 11 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-beanutils/commons-beanutils
# {'Version': '1.9.4', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '2,071', 'Date': 'Aug 14, 2019'}
# Elapsed time: 89.78976975003025 seconds
# ================== 12 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-codec/commons-codec
# {'Version': '1.17.1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '289', 'Date': 'Jul 12, 2024'}
# Elapsed time: 90.41267837502528 seconds
# ================== 13 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-collections/commons-collections
# {'Version': '3.2.2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '2,979', 'Date': 'Nov 12, 2015'}
# Elapsed time: 86.77070758299669 seconds
# ================== 14 / 94 ==================
# scraping: nan
# Encountered error, pay attention to this url: nan
# {'Version': '', 'Vulnerabilities': '', 'Date': ''}
# Elapsed time: 0.07735145802143961 seconds
# ================== 15 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.commons/commons-csv
# {'Version': '1.11.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '52', 'Date': 'May 03, 2024'}
# Elapsed time: 83.69408583297627 seconds
# ================== 16 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-dbcp/commons-dbcp
# {'Version': '1.4', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '1,247', 'Date': 'Feb 07, 2010'}
# Elapsed time: 109.3418819999788 seconds
# ================== 17 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-fileupload/commons-fileupload
# {'': '1.5.x', 'Version': '1.5', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '328', 'Date': 'Feb 13, 2023'}
# Elapsed time: 91.64838691696059 seconds
# ================== 18 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-httpclient/commons-httpclient
# {'Version': '3.1', 'Vulnerabilities': '1 vulnerability', 'Repository': 'Central', 'Usages': '2,519', 'Date': 'Aug 21, 2007'}
# Elapsed time: 89.08154529100284 seconds
# ================== 19 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-io/commons-io
# {'Version': '2.16.1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '1,680', 'Date': 'Apr 08, 2024'}
# Elapsed time: 88.5490820420091 seconds
# ================== 20 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-lang/commons-lang
# {'Version': '2.6', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '8,548', 'Date': 'Jan 16, 2011'}
# Elapsed time: 112.10230774997035 seconds
# ================== 21 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.commons/commons-lang3
# {'': '3.15.x', 'Version': '3.15.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '348', 'Date': 'Jul 17, 2024'}
# Elapsed time: 6.070425208017696 seconds
# ================== 22 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-logging/commons-logging
# {'': '1.3.x', 'Version': '1.3.3', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '24', 'Date': 'Jun 30, 2024'}
# Elapsed time: 81.33386862499174 seconds
# ================== 23 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-logging/commons-logging-api
# {'': '1.1.x', 'Version': '1.1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '459', 'Date': 'Jun 03, 2007'}
# Elapsed time: 85.18007391697029 seconds
# ================== 24 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-net/commons-net
# {'Version': '3.11.1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '40', 'Date': 'Jun 10, 2024'}
# Elapsed time: 81.7667907080031 seconds
# ================== 25 / 94 ==================
# scraping: https://mvnrepository.com/artifact/commons-pool/commons-pool
# {'Version': '1.6', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '841', 'Date': 'Jan 09, 2012'}
# Elapsed time: 85.55646945897024 seconds
# ================== 26 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.xhtmlrenderer/core-renderer
# {'Version': 'R8', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '39', 'Date': 'May 20, 2010'}
# Elapsed time: 85.16161266696872 seconds
# ================== 27 / 94 ==================
# scraping: https://mvnrepository.com/artifact/net.sourceforge.cpdetector/cpdetector
# {'Version': '1.0.7', 'Vulnerabilities': '', 'Repository': 'Nuiton', 'Usages': '5', 'Date': 'Apr 21, 2010'}
# Elapsed time: 85.92784945800668 seconds
# ================== 28 / 94 ==================
# scraping: https://mvnrepository.com/artifact/dom4j/dom4j
# {'Version': '1.6.1', 'Vulnerabilities': '2 vulnerabilities', 'Repository': 'Central', 'Usages': '2,267', 'Date': 'Feb 10, 2006'}
# Elapsed time: 85.15313774999231 seconds
# ================== 29 / 94 ==================
# scraping: https://mvnrepository.com/artifact/net.sf.ehcache/ehcache
# {'': '2.10.x', 'Version': '2.10.9.2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '137', 'Date': 'Apr 24, 2021'}
# Elapsed time: 84.29008233296918 seconds
# ================== 30 / 94 ==================
# scraping: https://mvnrepository.com/artifact/javax.persistence/ejb3-persistence
# {'Version': '1.0', 'Vulnerabilities': '', 'Repository': 'OpenMind', 'Usages': '0', 'Date': 'Jan 26, 2009'}
# Elapsed time: 12.377446916012559 seconds
# ================== 31 / 94 ==================
# scraping: https://mvnrepository.com/artifact/net.sf.ezmorph/ezmorph
# {'': '1.0.x', 'Version': '1.0.6', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '95', 'Date': 'Dec 26, 2008'}
# Elapsed time: 83.5318043330335 seconds
# ================== 32 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.fontbox/fontbox
# {'Version': '0.1.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '19', 'Date': 'Jun 29, 2007'}
# Elapsed time: 84.09191558294697 seconds
# ================== 33 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.freemarker/freemarker
# {'Version': '2.3.33', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '75', 'Date': 'Jun 01, 2024'}
# Elapsed time: 82.81852279097075 seconds
# ================== 34 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.hibernate/hibernate
# {'': '3.6.x', 'Version': '3.6.0.Beta2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '0', 'Date': 'Aug 04, 2010'}
# Elapsed time: 83.98065937502543 seconds
# ================== 35 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.hibernate/hibernate-annotations
# {'': '3.5.x', 'Version': '3.5.6-Final', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '72', 'Date': 'Sep 15, 2010'}
# Elapsed time: 80.23544399999082 seconds
# ================== 36 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.hibernate.common/hibernate-commons-annotations
# {'': '7.0.x', 'Version': '7.0.1.Final', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '4', 'Date': 'Jun 11, 2024'}
# Elapsed time: 98.46269187500002 seconds
# ================== 37 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.mnode.ical4j/ical4j
# {'': '4.0.x', 'Version': '4.0.2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '2', 'Date': 'Jul 20, 2024'}
# Elapsed time: 84.3273712079972 seconds
# ================== 38 / 94 ==================
# scraping: https://mvnrepository.com/artifact/com.itextpdf/itextpdf
# {'': '5.5.x', 'Version': '5.5.13.4', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '9', 'Date': 'Jun 13, 2024'}
# Elapsed time: 85.05996850004885 seconds
# ================== 39 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.jasypt/jasypt
# {'': '1.9.x', 'Version': '1.9.3', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '186', 'Date': 'May 26, 2019'}
# Elapsed time: 81.54979262501001 seconds
# ================== 40 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.jasypt/jasypt-hibernate3
# {'Version': '1.9.3', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '0', 'Date': 'May 26, 2019'}
# Elapsed time: 86.83342683303636 seconds
# ================== 41 / 94 ==================
# scraping: https://mvnrepository.com/artifact/net.sourceforge.javacsv/javacsv
# {'Version': '2.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '100', 'Date': 'Feb 20, 2008'}
# Elapsed time: 90.42290612496436 seconds
# ================== 42 / 94 ==================
# scraping: https://mvnrepository.com/artifact/jaxen/jaxen
# {'Version': '2.0.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '80', 'Date': 'Dec 03, 2022'}
# Elapsed time: 87.71620112500386 seconds
# ================== 43 / 94 ==================
# scraping: https://mvnrepository.com/artifact/com.derivclear/jexcel
# {'Version': '1.0', 'Vulnerabilities': '', 'Repository': 'EmergyaPub', 'Usages': '0', 'Date': 'Jul 18, 2022'}
# Elapsed time: 92.60349608300021 seconds
# ================== 44 / 94 ==================
# scraping: https://mvnrepository.com/artifact/com.jcraft/jsch
# {'Version': '0.1.55', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '486', 'Date': 'Nov 26, 2018'}
# Elapsed time: 80.56869995896704 seconds
# ================== 45 / 94 ==================
# scraping: https://mvnrepository.com/artifact/net.sf.json-lib/json-lib
# {'': '2.4.x', 'Version': '2.4', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '660', 'Date': 'Dec 14, 2010'}
# Elapsed time: 87.58018191700103 seconds
# ================== 46 / 94 ==================
# scraping: https://mvnrepository.com/artifact/javax.servlet/jstl
# {'': '1.2.x', 'Version': '1.2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '1,563', 'Date': 'Jun 23, 2011'}
# Elapsed time: 87.8714961669757 seconds
# ================== 47 / 94 ==================
# scraping: https://mvnrepository.com/artifact/net.sf.jt400/jt400
# {'': '20.0.x', 'Version': '20.0.7', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '4', 'Date': 'Feb 15, 2024'}
# Elapsed time: 89.76712191698607 seconds
# ================== 48 / 94 ==================
# scraping: https://mvnrepository.com/artifact/javax.transaction/jta
# {'Version': '1.1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '1,074', 'Date': 'Oct 28, 2008'}
# Elapsed time: 86.93908691598335 seconds
# ================== 49 / 94 ==================
# scraping: https://mvnrepository.com/artifact/com.github.junrar/junrar
# {'': '7.5.x', 'Version': '7.5.5', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '6', 'Date': 'Jul 18, 2023'}
# Elapsed time: 86.80377170804422 seconds
# ================== 50 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.logging.log4j/log4j-1.2-api
# {'': '3.0.x', 'Version': '3.0.0-beta2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '2', 'Date': 'Feb 21, 2024'}
# Elapsed time: 86.3676784170093 seconds
# ================== 51 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.logging.log4j/log4j-api
# {'': '3.0.x', 'Version': '3.0.0-beta2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '25', 'Date': 'Feb 21, 2024'}
# Elapsed time: 145.1208122500102 seconds
# ================== 52 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.logging.log4j/log4j-core
# {'': '3.0.x', 'Version': '3.0.0-beta2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '27', 'Date': 'Feb 21, 2024'}
# Elapsed time: 87.67217699997127 seconds
# ================== 53 / 94 ==================
# scraping: https://mvnrepository.com/artifact/com.microsoft.sqlserver/mssql-jdbc
# {'': '12.8.x', 'Version': '12.8.0.jre11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '2', 'Date': 'Jul 31, 2024'}
# Elapsed time: 34.309921415988356 seconds
# ================== 54 / 94 ==================
# scraping: https://mvnrepository.com/artifact/ognl/ognl
# {'': '3.4.x', 'Version': '3.4.3', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '9', 'Date': 'Apr 19, 2024'}
# Elapsed time: 108.04719849996036 seconds
# ================== 55 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.aop
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '7', 'Date': 'Apr 21, 2018'}
# Elapsed time: 91.39777866698569 seconds
# ================== 56 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-aop
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '25', 'Date': 'Jul 11, 2024'}
# Elapsed time: 86.00524279201636 seconds
# ================== 57 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.asm
# {'': '3.1.x', 'Version': '3.1.4.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '7', 'Date': 'Apr 21, 2018'}
# Elapsed time: 86.8323628330254 seconds
# ================== 58 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.beans
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '18', 'Date': 'Apr 21, 2018'}
# Elapsed time: 88.02532279101433 seconds
# ================== 59 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-beans
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '117', 'Date': 'Jul 11, 2024'}
# Elapsed time: 108.06980504101375 seconds
# ================== 60 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.context
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '18', 'Date': 'Apr 21, 2018'}
# Elapsed time: 87.23650008399272 seconds
# ================== 61 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-context
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '207', 'Date': 'Jul 11, 2024'}
# Elapsed time: 87.67853779200232 seconds
# ================== 62 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.context.support
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '3', 'Date': 'Apr 23, 2018'}
# Elapsed time: 79.41941158403642 seconds
# ================== 63 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-context-support
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '27', 'Date': 'Jul 11, 2024'}
# Elapsed time: 85.67535312502878 seconds
# ================== 64 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.core
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '18', 'Date': 'Apr 23, 2018'}
# Elapsed time: 82.50915333395824 seconds
# ================== 65 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-core
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '127', 'Date': 'Jul 11, 2024'}
# Elapsed time: 84.35240570799215 seconds
# ================== 66 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.expression
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '0', 'Date': 'Apr 23, 2018'}
# Elapsed time: 80.34662416699575 seconds
# ================== 67 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-expression
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '4', 'Date': 'Jul 11, 2024'}
# Elapsed time: 3.563347832998261 seconds
# ================== 68 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.jdbc
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '7', 'Date': 'Apr 23, 2018'}
# Elapsed time: 81.65725716704037 seconds
# ================== 69 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-jdbc
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '28', 'Date': 'Jul 11, 2024'}
# Elapsed time: 83.882121542003 seconds
# ================== 70 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.orm
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '2', 'Date': 'Apr 23, 2018'}
# Elapsed time: 82.55368270899635 seconds
# ================== 71 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-orm
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '10', 'Date': 'Jul 11, 2024'}
# Elapsed time: 79.16600237495732 seconds
# ================== 72 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.transaction
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '7', 'Date': 'Apr 21, 2018'}
# Elapsed time: 84.0748011249816 seconds
# ================== 73 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-tx
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '39', 'Date': 'Jul 11, 2024'}
# Elapsed time: 82.51639362500282 seconds
# ================== 74 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.web
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Plugins', 'Usages': '6', 'Date': 'Apr 21, 2018'}
# Elapsed time: 82.13212991697947 seconds
# ================== 75 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-web
# {'': '6.1.x', 'Version': '6.1.11', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '77', 'Date': 'Jul 11, 2024'}
# Elapsed time: 80.64257908303989 seconds
# ================== 76 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/org.springframework.web.servlet
# {'': '3.2.x', 'Version': '3.2.2.RELEASE', 'Vulnerabilities': '', 'Repository': 'Spring Lib Release', 'Usages': '3', 'Date': 'Mar 19, 2013'}
# Elapsed time: 82.0005813750322 seconds
# ================== 77 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework/spring-struts
# {'': '3.2.x', 'Version': '3.2.18.RELEASE', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '2', 'Date': 'Dec 21, 2016'}
# Elapsed time: 82.53551591699943 seconds
# ================== 78 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.pdfbox/pdfbox
# {'': '3.0.x', 'Version': '3.0.2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '51', 'Date': 'Mar 14, 2024'}
# Elapsed time: 82.835385125014 seconds
# ================== 79 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.poi/poi
# {'': '5.3.x', 'Version': '5.3.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '33', 'Date': 'Jul 02, 2024'}
# Elapsed time: 81.39001970802201 seconds
# ================== 80 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.poi/poi-excelant
# {'': '5.3.x', 'Version': '5.3.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '0', 'Date': 'Jul 02, 2024'}
# Elapsed time: 88.55768383300165 seconds
# ================== 81 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.poi/poi-ooxml
# {'': '5.3.x', 'Version': '5.3.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '50', 'Date': 'Jul 02, 2024'}
# Elapsed time: 83.0910440000007 seconds
# ================== 82 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.poi/poi-ooxml-schemas
# {'': '4.1.x', 'Version': '4.1.2', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '143', 'Date': 'Feb 14, 2020'}
# Elapsed time: 120.27495616697706 seconds
# ================== 83 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.poi/poi-scratchpad
# {'': '5.3.x', 'Version': '5.3.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '6', 'Date': 'Jul 02, 2024'}
# Elapsed time: 2.615784582972992 seconds
# ================== 84 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.quartz-scheduler/quartz
# {'': '2.5.x', 'Version': '2.5.0-rc1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '5', 'Date': 'Apr 29, 2023'}
# Elapsed time: 82.76561108400347 seconds
# ================== 85 / 94 ==================
# scraping: nan
# Encountered error, pay attention to this url: nan
# {'Version': '', 'Vulnerabilities': '', 'Date': ''}
# Elapsed time: 0.2509763330454007 seconds
# ================== 86 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.slf4j/slf4j-api
# {'': '2.1.x', 'Version': '2.1.0-alpha1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '37', 'Date': 'Jan 02, 2024'}
# Elapsed time: 82.70845629199175 seconds
# ================== 87 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.slf4j/slf4j-log4j12
# {'': '2.1.x', 'Version': '2.1.0-alpha1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '2', 'Date': 'Jan 02, 2024'}
# Elapsed time: 81.43439825001406 seconds
# ================== 88 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.springframework.security/spring-security-core
# {'': '6.3.x', 'Version': '6.3.1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '442', 'Date': 'Jun 17, 2024'}
# Elapsed time: 82.18541562499013 seconds
# ================== 89 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.struts/struts2-convention-plugin
# {'': '6.4.x', 'Version': '6.4.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '5', 'Date': 'Apr 20, 2024'}
# Elapsed time: 83.59861983399605 seconds
# ================== 90 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.struts/struts2-core
# {'': '6.4.x', 'Version': '6.4.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '14', 'Date': 'Apr 20, 2024'}
# Elapsed time: 84.34444750001421 seconds
# ================== 91 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.struts/struts2-json-plugin
# {'': '6.4.x', 'Version': '6.4.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '3', 'Date': 'Apr 20, 2024'}
# Elapsed time: 82.64325137500418 seconds
# ================== 92 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.struts/struts2-spring-plugin
# {'': '6.4.x', 'Version': '6.4.0', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '4', 'Date': 'Apr 20, 2024'}
# Elapsed time: 82.49589916702826 seconds
# ================== 93 / 94 ==================
# scraping: https://mvnrepository.com/artifact/org.apache.xmlbeans/xmlbeans
# {'': '5.2.x', 'Version': '5.2.1', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '17', 'Date': 'May 26, 2024'}
# Elapsed time: 82.2146157080424 seconds
# ================== 94 / 94 ==================
# scraping: https://mvnrepository.com/artifact/net.lingala.zip4j/zip4j
# {'': '2.11.x', 'Version': '2.11.5', 'Vulnerabilities': '', 'Repository': 'Central', 'Usages': '85', 'Date': 'Feb 22, 2023'}
# Elapsed time: 80.76364695903612 seconds
# Here are the urls that failed during fetching:
# {1: '中菲', 9: '中菲', 13: nan, 84: nan}

# %%
pprint.pprint(first_rows_of_version_table)
# Out:
# [{'Date': 'Jul 17, 2006',
#   'Repository': 'Central',
#   'Usages': '42',
#   'Version': '1.0.2',
#   'Vulnerabilities': ''},
#  {'Date': '', 'Version': '', 'Vulnerabilities': ''},
#  {'Date': 'Jan 14, 2007',
#   'Repository': 'Central',
#   'Usages': '0',
#   'Version': '3.0ea8',
#   'Vulnerabilities': ''},
#  {'Date': 'Jan 14, 2007',
#   'Repository': 'Central',
#   'Usages': '0',
#   'Version': '3.0ea8',
#   'Vulnerabilities': ''},
#  {'Date': 'Dec 28, 2015',
#   'Repository': 'Central',
#   'Usages': '937',
#   'Version': '1.0',
#   'Vulnerabilities': ''},
#  {'': '9.7.x',
#   'Date': 'Mar 23, 2024',
#   'Repository': 'Central',
#   'Usages': '228',
#   'Version': '9.7',
#   'Vulnerabilities': ''},
#  {'': '9.7.x',
#   'Date': 'Mar 23, 2024',
#   'Repository': 'Central',
#   'Usages': '90',
#   'Version': '9.7',
#   'Vulnerabilities': ''},
#  {'': '3.3.x',
#   'Date': 'Aug 12, 2019',
#   'Repository': 'Central',
#   'Usages': '220',
#   'Version': '3.3.0',
#   'Vulnerabilities': ''},
#  {'Date': 'Jun 14, 2023',
#   'Repository': 'Central',
#   'Usages': '0',
#   'Version': '1.4.0',
#   'Vulnerabilities': ''},
#  {'Date': '', 'Version': '', 'Vulnerabilities': ''},
#  {'Date': 'Aug 14, 2019',
#   'Repository': 'Central',
#   'Usages': '2,071',
#   'Version': '1.9.4',
#   'Vulnerabilities': ''},
#  {'Date': 'Jul 12, 2024',
#   'Repository': 'Central',
#   'Usages': '289',
#   'Version': '1.17.1',
#   'Vulnerabilities': ''},
#  {'Date': 'Nov 12, 2015',
#   'Repository': 'Central',
#   'Usages': '2,979',
#   'Version': '3.2.2',
#   'Vulnerabilities': ''},
#  {'Date': '', 'Version': '', 'Vulnerabilities': ''},
#  {'Date': 'May 03, 2024',
#   'Repository': 'Central',
#   'Usages': '52',
#   'Version': '1.11.0',
#   'Vulnerabilities': ''},
#  {'Date': 'Feb 07, 2010',
#   'Repository': 'Central',
#   'Usages': '1,247',
#   'Version': '1.4',
#   'Vulnerabilities': ''},
#  {'': '1.5.x',
#   'Date': 'Feb 13, 2023',
#   'Repository': 'Central',
#   'Usages': '328',
#   'Version': '1.5',
#   'Vulnerabilities': ''},
#  {'Date': 'Aug 21, 2007',
#   'Repository': 'Central',
#   'Usages': '2,519',
#   'Version': '3.1',
#   'Vulnerabilities': '1 vulnerability'},
#  {'Date': 'Apr 08, 2024',
#   'Repository': 'Central',
#   'Usages': '1,680',
#   'Version': '2.16.1',
#   'Vulnerabilities': ''},
#  {'Date': 'Jan 16, 2011',
#   'Repository': 'Central',
#   'Usages': '8,548',
#   'Version': '2.6',
#   'Vulnerabilities': ''},
#  {'': '3.15.x',
#   'Date': 'Jul 17, 2024',
#   'Repository': 'Central',
#   'Usages': '348',
#   'Version': '3.15.0',
#   'Vulnerabilities': ''},
#  {'': '1.3.x',
#   'Date': 'Jun 30, 2024',
#   'Repository': 'Central',
#   'Usages': '24',
#   'Version': '1.3.3',
#   'Vulnerabilities': ''},
#  {'': '1.1.x',
#   'Date': 'Jun 03, 2007',
#   'Repository': 'Central',
#   'Usages': '459',
#   'Version': '1.1',
#   'Vulnerabilities': ''},
#  {'Date': 'Jun 10, 2024',
#   'Repository': 'Central',
#   'Usages': '40',
#   'Version': '3.11.1',
#   'Vulnerabilities': ''},
#  {'Date': 'Jan 09, 2012',
#   'Repository': 'Central',
#   'Usages': '841',
#   'Version': '1.6',
#   'Vulnerabilities': ''},
#  {'Date': 'May 20, 2010',
#   'Repository': 'Central',
#   'Usages': '39',
#   'Version': 'R8',
#   'Vulnerabilities': ''},
#  {'Date': 'Apr 21, 2010',
#   'Repository': 'Nuiton',
#   'Usages': '5',
#   'Version': '1.0.7',
#   'Vulnerabilities': ''},
#  {'Date': 'Feb 10, 2006',
#   'Repository': 'Central',
#   'Usages': '2,267',
#   'Version': '1.6.1',
#   'Vulnerabilities': '2 vulnerabilities'},
#  {'': '2.10.x',
#   'Date': 'Apr 24, 2021',
#   'Repository': 'Central',
#   'Usages': '137',
#   'Version': '2.10.9.2',
#   'Vulnerabilities': ''},
#  {'Date': 'Jan 26, 2009',
#   'Repository': 'OpenMind',
#   'Usages': '0',
#   'Version': '1.0',
#   'Vulnerabilities': ''},
#  {'': '1.0.x',
#   'Date': 'Dec 26, 2008',
#   'Repository': 'Central',
#   'Usages': '95',
#   'Version': '1.0.6',
#   'Vulnerabilities': ''},
#  {'Date': 'Jun 29, 2007',
#   'Repository': 'Central',
#   'Usages': '19',
#   'Version': '0.1.0',
#   'Vulnerabilities': ''},
#  {'Date': 'Jun 01, 2024',
#   'Repository': 'Central',
#   'Usages': '75',
#   'Version': '2.3.33',
#   'Vulnerabilities': ''},
#  {'': '3.6.x',
#   'Date': 'Aug 04, 2010',
#   'Repository': 'Central',
#   'Usages': '0',
#   'Version': '3.6.0.Beta2',
#   'Vulnerabilities': ''},
#  {'': '3.5.x',
#   'Date': 'Sep 15, 2010',
#   'Repository': 'Central',
#   'Usages': '72',
#   'Version': '3.5.6-Final',
#   'Vulnerabilities': ''},
#  {'': '7.0.x',
#   'Date': 'Jun 11, 2024',
#   'Repository': 'Central',
#   'Usages': '4',
#   'Version': '7.0.1.Final',
#   'Vulnerabilities': ''},
#  {'': '4.0.x',
#   'Date': 'Jul 20, 2024',
#   'Repository': 'Central',
#   'Usages': '2',
#   'Version': '4.0.2',
#   'Vulnerabilities': ''},
#  {'': '5.5.x',
#   'Date': 'Jun 13, 2024',
#   'Repository': 'Central',
#   'Usages': '9',
#   'Version': '5.5.13.4',
#   'Vulnerabilities': ''},
#  {'': '1.9.x',
#   'Date': 'May 26, 2019',
#   'Repository': 'Central',
#   'Usages': '186',
#   'Version': '1.9.3',
#   'Vulnerabilities': ''},
#  {'Date': 'May 26, 2019',
#   'Repository': 'Central',
#   'Usages': '0',
#   'Version': '1.9.3',
#   'Vulnerabilities': ''},
#  {'Date': 'Feb 20, 2008',
#   'Repository': 'Central',
#   'Usages': '100',
#   'Version': '2.0',
#   'Vulnerabilities': ''},
#  {'Date': 'Dec 03, 2022',
#   'Repository': 'Central',
#   'Usages': '80',
#   'Version': '2.0.0',
#   'Vulnerabilities': ''},
#  {'Date': 'Jul 18, 2022',
#   'Repository': 'EmergyaPub',
#   'Usages': '0',
#   'Version': '1.0',
#   'Vulnerabilities': ''},
#  {'Date': 'Nov 26, 2018',
#   'Repository': 'Central',
#   'Usages': '486',
#   'Version': '0.1.55',
#   'Vulnerabilities': ''},
#  {'': '2.4.x',
#   'Date': 'Dec 14, 2010',
#   'Repository': 'Central',
#   'Usages': '660',
#   'Version': '2.4',
#   'Vulnerabilities': ''},
#  {'': '1.2.x',
#   'Date': 'Jun 23, 2011',
#   'Repository': 'Central',
#   'Usages': '1,563',
#   'Version': '1.2',
#   'Vulnerabilities': ''},
#  {'': '20.0.x',
#   'Date': 'Feb 15, 2024',
#   'Repository': 'Central',
#   'Usages': '4',
#   'Version': '20.0.7',
#   'Vulnerabilities': ''},
#  {'Date': 'Oct 28, 2008',
#   'Repository': 'Central',
#   'Usages': '1,074',
#   'Version': '1.1',
#   'Vulnerabilities': ''},
#  {'': '7.5.x',
#   'Date': 'Jul 18, 2023',
#   'Repository': 'Central',
#   'Usages': '6',
#   'Version': '7.5.5',
#   'Vulnerabilities': ''},
#  {'': '3.0.x',
#   'Date': 'Feb 21, 2024',
#   'Repository': 'Central',
#   'Usages': '2',
#   'Version': '3.0.0-beta2',
#   'Vulnerabilities': ''},
#  {'': '3.0.x',
#   'Date': 'Feb 21, 2024',
#   'Repository': 'Central',
#   'Usages': '25',
#   'Version': '3.0.0-beta2',
#   'Vulnerabilities': ''},
#  {'': '3.0.x',
#   'Date': 'Feb 21, 2024',
#   'Repository': 'Central',
#   'Usages': '27',
#   'Version': '3.0.0-beta2',
#   'Vulnerabilities': ''},
#  {'': '12.8.x',
#   'Date': 'Jul 31, 2024',
#   'Repository': 'Central',
#   'Usages': '2',
#   'Version': '12.8.0.jre11',
#   'Vulnerabilities': ''},
#  {'': '3.4.x',
#   'Date': 'Apr 19, 2024',
#   'Repository': 'Central',
#   'Usages': '9',
#   'Version': '3.4.3',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 21, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '7',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '25',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.1.x',
#   'Date': 'Apr 21, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '7',
#   'Version': '3.1.4.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 21, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '18',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '117',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 21, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '18',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '207',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 23, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '3',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '27',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 23, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '18',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '127',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 23, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '0',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '4',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 23, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '7',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '28',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 23, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '2',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '10',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 21, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '7',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '39',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Apr 21, 2018',
#   'Repository': 'Spring Plugins',
#   'Usages': '6',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '6.1.x',
#   'Date': 'Jul 11, 2024',
#   'Repository': 'Central',
#   'Usages': '77',
#   'Version': '6.1.11',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Mar 19, 2013',
#   'Repository': 'Spring Lib Release',
#   'Usages': '3',
#   'Version': '3.2.2.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '3.2.x',
#   'Date': 'Dec 21, 2016',
#   'Repository': 'Central',
#   'Usages': '2',
#   'Version': '3.2.18.RELEASE',
#   'Vulnerabilities': ''},
#  {'': '3.0.x',
#   'Date': 'Mar 14, 2024',
#   'Repository': 'Central',
#   'Usages': '51',
#   'Version': '3.0.2',
#   'Vulnerabilities': ''},
#  {'': '5.3.x',
#   'Date': 'Jul 02, 2024',
#   'Repository': 'Central',
#   'Usages': '33',
#   'Version': '5.3.0',
#   'Vulnerabilities': ''},
#  {'': '5.3.x',
#   'Date': 'Jul 02, 2024',
#   'Repository': 'Central',
#   'Usages': '0',
#   'Version': '5.3.0',
#   'Vulnerabilities': ''},
#  {'': '5.3.x',
#   'Date': 'Jul 02, 2024',
#   'Repository': 'Central',
#   'Usages': '50',
#   'Version': '5.3.0',
#   'Vulnerabilities': ''},
#  {'': '4.1.x',
#   'Date': 'Feb 14, 2020',
#   'Repository': 'Central',
#   'Usages': '143',
#   'Version': '4.1.2',
#   'Vulnerabilities': ''},
#  {'': '5.3.x',
#   'Date': 'Jul 02, 2024',
#   'Repository': 'Central',
#   'Usages': '6',
#   'Version': '5.3.0',
#   'Vulnerabilities': ''},
#  {'': '2.5.x',
#   'Date': 'Apr 29, 2023',
#   'Repository': 'Central',
#   'Usages': '5',
#   'Version': '2.5.0-rc1',
#   'Vulnerabilities': ''},
#  {'Date': '', 'Version': '', 'Vulnerabilities': ''},
#  {'': '2.1.x',
#   'Date': 'Jan 02, 2024',
#   'Repository': 'Central',
#   'Usages': '37',
#   'Version': '2.1.0-alpha1',
#   'Vulnerabilities': ''},
#  {'': '2.1.x',
#   'Date': 'Jan 02, 2024',
#   'Repository': 'Central',
#   'Usages': '2',
#   'Version': '2.1.0-alpha1',
#   'Vulnerabilities': ''},
#  {'': '6.3.x',
#   'Date': 'Jun 17, 2024',
#   'Repository': 'Central',
#   'Usages': '442',
#   'Version': '6.3.1',
#   'Vulnerabilities': ''},
#  {'': '6.4.x',
#   'Date': 'Apr 20, 2024',
#   'Repository': 'Central',
#   'Usages': '5',
#   'Version': '6.4.0',
#   'Vulnerabilities': ''},
#  {'': '6.4.x',
#   'Date': 'Apr 20, 2024',
#   'Repository': 'Central',
#   'Usages': '14',
#   'Version': '6.4.0',
#   'Vulnerabilities': ''},
#  {'': '6.4.x',
#   'Date': 'Apr 20, 2024',
#   'Repository': 'Central',
#   'Usages': '3',
#   'Version': '6.4.0',
#   'Vulnerabilities': ''},
#  {'': '6.4.x',
#   'Date': 'Apr 20, 2024',
#   'Repository': 'Central',
#   'Usages': '4',
#   'Version': '6.4.0',
#   'Vulnerabilities': ''},
#  {'': '5.2.x',
#   'Date': 'May 26, 2024',
#   'Repository': 'Central',
#   'Usages': '17',
#   'Version': '5.2.1',
#   'Vulnerabilities': ''},
#  {'': '2.11.x',
#   'Date': 'Feb 22, 2023',
#   'Repository': 'Central',
#   'Usages': '85',
#   'Version': '2.11.5',
#   'Vulnerabilities': ''}]

# %% [markdown]
# ### step 3: organize data and parse to desired format

# %%
# Define formatting methods
import math
from datetime import datetime
def formatLibrary(libName, versionNumber):
    if (not libName or (type(libName) is float and math.isnan(libName))):
        return math.nan
    libNameList =libName.split('-')
    extension = libNameList[-1].split('.')[-1]
    return "".join(libNameList[:-1]) + "-" + versionNumber + "." + extension

def formatVulnerability(vulnerabilitiesString):
    if (not vulnerabilitiesString or (type(vulnerabilitiesString) is float and math.isnan(vulnerabilitiesString))):
        return math.nan
    return vulnerabilitiesString.split()[0]

def formatDate(dateString):
    if (not dateString or (type(dateString) is float and math.isnan(dateString))):
        return math.nan
    date_format = "%b %d, %Y"
    return datetime.strptime(dateString, date_format)

# %%
for i in range(len(dependencies[:])):
    row = first_rows_of_version_table[i]
    versionNumber = row["Version"]
    dateString = row["Date"]
    vulnerabilitiesString = row["Vulnerabilities"]
    
    formatedVersion = formatLibrary(dependencies[i]["library"], versionNumber)
    formatedVulnerability = formatVulnerability(vulnerabilitiesString)
    formatedDate = formatDate(dateString)
    
    dependencies[i]['date']= formatedDate
    dependencies[i]['library']= formatedVersion
    dependencies[i]['vulnerabilities']= formatedVulnerability

pprint.pprint(dependencies)
# Out:
# [{'date': datetime.datetime(2006, 7, 17, 0, 0),
#   'library': 'activation-1.0.2.jar',
#   'url': 'https://mvnrepository.com/artifact/javax.xml.bind/activation',
#   'vulnerabilities': nan},
#  {'date': nan, 'library': nan, 'url': '中菲', 'vulnerabilities': nan},
#  {'date': datetime.datetime(2007, 1, 14, 0, 0),
#   'library': 'antlr-3.0ea8.jar',
#   'url': 'https://mvnrepository.com/artifact/antlr/antlr',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2007, 1, 14, 0, 0),
#   'library': 'antlr-3.0ea8.jar',
#   'url': 'https://mvnrepository.com/artifact/antlr/antlr',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2015, 12, 28, 0, 0),
#   'library': 'aopalliance-1.0.jar',
#   'url': 'https://mvnrepository.com/artifact/aopalliance/aopalliance',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 3, 23, 0, 0),
#   'library': 'asm-9.7.jar',
#   'url': 'https://mvnrepository.com/artifact/org.ow2.asm/asm',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 3, 23, 0, 0),
#   'library': 'asmcommons-9.7.jar',
#   'url': 'https://mvnrepository.com/artifact/org.ow2.asm/asm-commons',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2019, 8, 12, 0, 0),
#   'library': 'cglibnodep-3.3.0.jar',
#   'url': 'https://mvnrepository.com/artifact/cglib/cglib-nodep',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2023, 6, 14, 0, 0),
#   'library': 'chardet-1.4.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.webjars.npm/chardet',
#   'vulnerabilities': nan},
#  {'date': nan, 'library': nan, 'url': '中菲', 'vulnerabilities': nan},
#  {'date': datetime.datetime(2019, 8, 14, 0, 0),
#   'library': 'commonsbeanutils-1.9.4.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-beanutils/commons-beanutils',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 12, 0, 0),
#   'library': 'commonscodec-1.17.1.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-codec/commons-codec',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2015, 11, 12, 0, 0),
#   'library': 'commonscollections-3.2.2.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-collections/commons-collections',
#   'vulnerabilities': nan},
#  {'date': nan, 'library': nan, 'url': '', 'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 5, 3, 0, 0),
#   'library': 'commonscsv-1.11.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.commons/commons-csv',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2010, 2, 7, 0, 0),
#   'library': 'commonsdbcp-1.4.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-dbcp/commons-dbcp',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2023, 2, 13, 0, 0),
#   'library': 'commonsfileupload-1.5.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-fileupload/commons-fileupload',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2007, 8, 21, 0, 0),
#   'library': 'commonshttpclient-3.1.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-httpclient/commons-httpclient',
#   'vulnerabilities': '1'},
#  {'date': datetime.datetime(2024, 4, 8, 0, 0),
#   'library': 'commonsio-2.16.1.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-io/commons-io',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2011, 1, 16, 0, 0),
#   'library': 'commonslang-2.6.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-lang/commons-lang',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 17, 0, 0),
#   'library': 'commonslang3-3.15.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.commons/commons-lang3',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 6, 30, 0, 0),
#   'library': 'commonslogging-1.3.3.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-logging/commons-logging',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2007, 6, 3, 0, 0),
#   'library': 'commonsloggingapi-1.1.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-logging/commons-logging-api',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 6, 10, 0, 0),
#   'library': 'commonsnet-3.11.1.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-net/commons-net',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2012, 1, 9, 0, 0),
#   'library': 'commonspool-1.6.jar',
#   'url': 'https://mvnrepository.com/artifact/commons-pool/commons-pool',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2010, 5, 20, 0, 0),
#   'library': 'corerenderer-R8.jar',
#   'url': 'https://mvnrepository.com/artifact/org.xhtmlrenderer/core-renderer',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2010, 4, 21, 0, 0),
#   'library': 'cpdetector-1.0.7.jar',
#   'url': 'https://mvnrepository.com/artifact/net.sourceforge.cpdetector/cpdetector',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2006, 2, 10, 0, 0),
#   'library': 'dom4j-1.6.1.jar',
#   'url': 'https://mvnrepository.com/artifact/dom4j/dom4j',
#   'vulnerabilities': '2'},
#  {'date': datetime.datetime(2021, 4, 24, 0, 0),
#   'library': 'ehcache-2.10.9.2.jar',
#   'url': 'https://mvnrepository.com/artifact/net.sf.ehcache/ehcache',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2009, 1, 26, 0, 0),
#   'library': 'ejb3persistence-1.0.jar',
#   'url': 'https://mvnrepository.com/artifact/javax.persistence/ejb3-persistence',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2008, 12, 26, 0, 0),
#   'library': 'ezmorph-1.0.6.jar',
#   'url': 'https://mvnrepository.com/artifact/net.sf.ezmorph/ezmorph',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2007, 6, 29, 0, 0),
#   'library': 'fontbox-0.1.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.fontbox/fontbox',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 6, 1, 0, 0),
#   'library': 'freemarker-2.3.33.jar',
#   'url': 'https://mvnrepository.com/artifact/org.freemarker/freemarker',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2010, 8, 4, 0, 0),
#   'library': 'hibernate-3.6.0.Beta2.jar',
#   'url': 'https://mvnrepository.com/artifact/org.hibernate/hibernate',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2010, 9, 15, 0, 0),
#   'library': 'hibernateannotations3.5.63.5.6-3.5.6-Final.jar',
#   'url': 'https://mvnrepository.com/artifact/org.hibernate/hibernate-annotations',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 6, 11, 0, 0),
#   'library': 'hibernatecommonsannotations-7.0.1.Final.jar',
#   'url': 'https://mvnrepository.com/artifact/org.hibernate.common/hibernate-commons-annotations',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 20, 0, 0),
#   'library': 'ical4j-4.0.2.jar ',
#   'url': 'https://mvnrepository.com/artifact/org.mnode.ical4j/ical4j',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 6, 13, 0, 0),
#   'library': 'jasypt-5.5.13.4.jar',
#   'url': 'https://mvnrepository.com/artifact/com.itextpdf/itextpdf',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2019, 5, 26, 0, 0),
#   'library': 'jasypthibernate3-1.9.3.jar',
#   'url': 'https://mvnrepository.com/artifact/org.jasypt/jasypt',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2019, 5, 26, 0, 0),
#   'library': 'javacsv-1.9.3.jar',
#   'url': 'https://mvnrepository.com/artifact/org.jasypt/jasypt-hibernate3',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2008, 2, 20, 0, 0),
#   'library': 'javassist3.20.0-2.0.jar',
#   'url': 'https://mvnrepository.com/artifact/net.sourceforge.javacsv/javacsv',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2022, 12, 3, 0, 0),
#   'library': 'jaxen-2.0.0.jar',
#   'url': 'https://mvnrepository.com/artifact/jaxen/jaxen',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2022, 7, 18, 0, 0),
#   'library': 'jexcel-1.0.jar',
#   'url': 'https://mvnrepository.com/artifact/com.derivclear/jexcel',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 11, 26, 0, 0),
#   'library': 'jsch-0.1.55.jar',
#   'url': 'https://mvnrepository.com/artifact/com.jcraft/jsch',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2010, 12, 14, 0, 0),
#   'library': 'jsonlib-2.4.jar',
#   'url': 'https://mvnrepository.com/artifact/net.sf.json-lib/json-lib',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2011, 6, 23, 0, 0),
#   'library': 'jstl-1.2.jar',
#   'url': 'https://mvnrepository.com/artifact/javax.servlet/jstl',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 2, 15, 0, 0),
#   'library': 'jt400-20.0.7.jar',
#   'url': 'https://mvnrepository.com/artifact/net.sf.jt400/jt400',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2008, 10, 28, 0, 0),
#   'library': 'jta-1.1.jar',
#   'url': 'https://mvnrepository.com/artifact/javax.transaction/jta',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2023, 7, 18, 0, 0),
#   'library': 'junrar-7.5.5.jar',
#   'url': 'https://mvnrepository.com/artifact/com.github.junrar/junrar',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 2, 21, 0, 0),
#   'library': 'log4j1.2api3.0.03.0.03.0.0-3.0.0-beta2.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.logging.log4j/log4j-1.2-api',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 2, 21, 0, 0),
#   'library': 'log4japi3.0.03.0.03.0.0-3.0.0-beta2.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.logging.log4j/log4j-api',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 2, 21, 0, 0),
#   'library': 'log4jcore3.0.03.0.03.0.0-3.0.0-beta2.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.logging.log4j/log4j-core',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 31, 0, 0),
#   'library': 'mssqljdbc-12.8.0.jre11.jar',
#   'url': 'https://mvnrepository.com/artifact/com.microsoft.sqlserver/mssql-jdbc',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 4, 19, 0, 0),
#   'library': 'ognl-3.4.3.jar',
#   'url': 'https://mvnrepository.com/artifact/ognl/ognl',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 21, 0, 0),
#   'library': 'org.springframework.aop-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.aop',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springaop-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-aop',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 21, 0, 0),
#   'library': 'org.springframework.asm-3.1.4.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.asm',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 21, 0, 0),
#   'library': 'org.springframework.beans-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.beans',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springbeans-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-beans',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 21, 0, 0),
#   'library': 'org.springframework.context-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.context',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springcontext-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-context',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 23, 0, 0),
#   'library': 'org.springframework.context.support-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.context.support',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springcontextsupport-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-context-support',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 23, 0, 0),
#   'library': 'org.springframework.core-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.core',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springcore-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-core',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 23, 0, 0),
#   'library': 'org.springframework.expression-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.expression',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springexpression-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-expression',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 23, 0, 0),
#   'library': 'org.springframework.jdbc-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.jdbc',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springjdbc-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-jdbc',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 23, 0, 0),
#   'library': 'org.springframework.orm-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.orm',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springorm-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-orm',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 21, 0, 0),
#   'library': 'org.springframework.transaction-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.transaction',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springtx-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-tx',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2018, 4, 21, 0, 0),
#   'library': 'org.springframework.web-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.web',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 11, 0, 0),
#   'library': 'springweb-6.1.11.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-web',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2013, 3, 19, 0, 0),
#   'library': 'org.springframework.web.servlet-3.2.2.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/org.springframework.web.servlet',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2016, 12, 21, 0, 0),
#   'library': 'org.springframework.web.struts-3.2.18.RELEASE.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework/spring-struts',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 3, 14, 0, 0),
#   'library': 'pdfbox-3.0.2.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.pdfbox/pdfbox',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 2, 0, 0),
#   'library': 'poi-5.3.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.poi/poi',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 2, 0, 0),
#   'library': 'poiexcelant-5.3.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.poi/poi-excelant',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 2, 0, 0),
#   'library': 'poiooxml-5.3.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.poi/poi-ooxml',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2020, 2, 14, 0, 0),
#   'library': 'poiooxmlschemas-4.1.2.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.poi/poi-ooxml-schemas',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 7, 2, 0, 0),
#   'library': 'poiscratchpad-5.3.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.poi/poi-scratchpad',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2023, 4, 29, 0, 0),
#   'library': 'quartz2.5.02.5.02.5.0-2.5.0-rc1.jar',
#   'url': 'https://mvnrepository.com/artifact/org.quartz-scheduler/quartz',
#   'vulnerabilities': nan},
#  {'date': nan, 'library': nan, 'url': '', 'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 1, 2, 0, 0),
#   'library': 'slf4japi2.1.02.1.02.1.0-2.1.0-alpha1.jar',
#   'url': 'https://mvnrepository.com/artifact/org.slf4j/slf4j-api',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 1, 2, 0, 0),
#   'library': 'slf4jlog4j122.0.02.1.02.1.0-2.1.0-alpha1.jar',
#   'url': 'https://mvnrepository.com/artifact/org.slf4j/slf4j-log4j12',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 6, 17, 0, 0),
#   'library': 'springsecuritycore-6.3.1.jar',
#   'url': 'https://mvnrepository.com/artifact/org.springframework.security/spring-security-core',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 4, 20, 0, 0),
#   'library': 'struts2conventionplugin-6.4.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.struts/struts2-convention-plugin',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 4, 20, 0, 0),
#   'library': 'struts2core-6.4.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.struts/struts2-core',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 4, 20, 0, 0),
#   'library': 'struts2jsonplugin-6.4.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.struts/struts2-json-plugin',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 4, 20, 0, 0),
#   'library': 'struts2springplugin-6.4.0.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.struts/struts2-spring-plugin',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2024, 5, 26, 0, 0),
#   'library': 'xmlbeans-5.2.1.jar',
#   'url': 'https://mvnrepository.com/artifact/org.apache.xmlbeans/xmlbeans',
#   'vulnerabilities': nan},
#  {'date': datetime.datetime(2023, 2, 22, 0, 0),
#   'library': 'zip4j-2.11.5.jar',
#   'url': 'https://mvnrepository.com/artifact/net.lingala.zip4j/zip4j',
#   'vulnerabilities': nan}]

# %% [markdown]
# ### step 4: save data as a new sheet in excel

# %%
# write to a json file
import json

formatted_date = datetime.now().strftime('%Y%m%d')
filename = f'{formatted_date}_dependencies.json'

dep_copy = dependencies[:]
for dep in dep_copy:
    for k, value in dep.items():
        if isinstance(value, float) and math.isnan(value):
            dep[k] = ""
        if isinstance(value, datetime):
            dep[k] = value.isoformat()


# Writing the dictionary to a JSON file
with open(filename, 'w') as file:
    json.dump(dep_copy, file, indent=4, ensure_ascii=False,)

# %%
from openpyxl import load_workbook

# Create a new sheet in excel
workbook = load_workbook(excelPath)
sheet_to_duplicate = workbook.worksheets[0]

# Duplicate the sheet
new_sheet = workbook.copy_worksheet(sheet_to_duplicate)
formatted_date = datetime.now().strftime('%Y%m%d') # Format the date as 'YYYYMMDD'
new_sheet.title = "t" + str(formatted_date)

workbook._sheets.insert(0, workbook._sheets.pop(workbook.sheetnames.index(new_sheet.title)))

# Save the workbook
workbook.save(excelPath)

print(f"Duplicated '{sheet_to_duplicate.title}' as '{new_sheet.title}' in '{excelPath}'")
# Out:
# Duplicated 't202408071' as 't202408072' in '/Users/yenshuohsu/DDSC/MavenWebScrapping/永豐.保管系統.Lib元件版本清單.20240630.xlsx'

# %%
headers = ['Date', 'Library', 'URL', 'Vulnerabilities']

# Write data rows
for row_idx, row_data in enumerate(dependencies, start=3):
    new_sheet.cell(row=row_idx, column=6, value=row_data.get('library'))
    new_sheet.cell(row=row_idx, column=7, value=row_data.get('vulnerabilities'))
    new_sheet.cell(row=row_idx, column=9, value=row_data.get('date'))
workbook.save(excelPath)
